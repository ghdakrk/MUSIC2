# %%
import scipy as cp
from scipy.io.wavfile import read
from scipy.io.wavfile import write

# %%
music = read('sax_boom.wav')

# %%
import numpy as np
music1 = music[1][:839**2]

# %%
temp = [i for i in range(1,100,10)]
temp
# Out:
# [1, 11, 21, 31, 41, 51, 61, 71, 81, 91]

# %%
music_dict={i: music[1][i:i+100]  for i in range(0, 10000, 100)}

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.imshow(music_dict[0].reshape(10,10), cmap=plt.cm.Blues_r)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.imshow(music_dict[100].reshape(10,10), cmap=plt.cm.Blues_r)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.imshow(music_dict[200].reshape(10,10), cmap=plt.cm.Blues_r)
plt.show()
